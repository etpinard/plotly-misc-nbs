# %% [markdown]
# # Gapminder data choropleths

# %%
import plotly.plotly as py
import plotly.tools as tls
import pandas as pd
import json
import urllib2
import re

# %% [markdown]
# The most famous gapminder data is featured in [Hans Rosling](https://en.wikipedia.org/wiki/Hans_Rosling)'s bubble charts (see a plotly version [here](https://plot.ly/~etpinard/191/fig-31b-hans-roslings-bubble-chart-for-the-year-2007/)).
#
# In this notebook, we'll explore the same dataset using plotly choropleths.

# %%
# big thanks to Jennifer Bryan!
df_full = pd.read_csv('http://www.stat.ubc.ca/~jenny/notOcto/STAT545A/examples/gapminder/data/gapminderDataFiveYear.txt', sep='\t')

df_full.head()
# Out:
#        country  year       pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460      Asia   36.088  739.981106
#
# [5 rows x 6 columns]

# %% [markdown]
# Select a year and truncate the dataframe

# %%
# Choose a year, find other years with df['year'].unique()
the_year = 2007   

# Find indices corresponding to 'the_year'
i_year = (df_full['year'] == the_year)

# Grab all rows correponding to 'the_year'
df = df_full[i_year]

# %% [markdown]
# Plotly uses [ISO-3](https://en.wikipedia.org/wiki/ISO_3166-1_alpha-3) identifier codes to draw choropleths.
#
# The JSON below will help us convert the country names found in the Wikipedia table to ISO-3 codes.

# %%
get_iso3 = json.load(urllib2.urlopen('https://raw.githubusercontent.com/etpinard/country-iso3/master/get-iso3.json'))

get_iso3
# Out:
# [{u'iso3': u'AFG', u'regex': u'afghan'},
#  {u'iso3': u'ALA', u'regex': u'\\b(a|\xe5)land'},
#  {u'iso3': u'ALB', u'regex': u'albania'},
#  {u'iso3': u'DZA', u'regex': u'algeria'},
#  {u'iso3': u'ASM', u'regex': u'^(?=.*americ).*samoa'},
#  {u'iso3': u'AND', u'regex': u'andorra'},
#  {u'iso3': u'AGO', u'regex': u'angola'},
#  {u'iso3': u'AIA', u'regex': u'anguill?a'},
#  {u'iso3': u'ATA', u'regex': u'antarctica'},
#  {u'iso3': u'ATG', u'regex': u'antigua'},
#  {u'iso3': u'ARG', u'regex': u'argentin'},
#  {u'iso3': u'ARM', u'regex': u'armenia'},
#  {u'iso3': u'ABW', u'regex': u'^(?!.*bonaire).*\\baruba'},
#  {u'iso3': u'AUS', u'regex': u'australia'},
#  {u'iso3': u'AUT', u'regex': u'^(?!.*hungary).*austria|\\baust.*\\bemp'},
#  {u'iso3': u'AZE', u'regex': u'azerbaijan'},
#  {u'iso3': u'BHS', u'regex': u'bahamas'},
#  {u'iso3': u'BHR', u'regex': u'bahrain'},
#  {u'iso3': u'BGD', u'regex': u'bangladesh|^(?=.*east).*paki?stan'},
#  {u'iso3': u'BRB', u'regex': u'barbados'},
#  {u'iso3': u'BLR', u'regex': u'belarus|byelo'},
#  {u'iso3': u'BEL', u'regex': u'^(?!.*luxem).*belgium'},
#  {u'iso3': u'BLZ', u'regex': u'belize|^(?=.*british).*honduras'},
#  {u'iso3': u'BEN', u'regex': u'benin|dahome'},
#  {u'iso3': u'BMU', u'regex': u'bermuda'},
#  {u'iso3': u'BTN', u'regex': u'bhutan'},
#  {u'iso3': u'BOL', u'regex': u'bolivia'},
#  {u'iso3': u'BES',
#   u'regex': u'^(?=.*bonaire).*eustatius|^(?=.*carib).*netherlands|\\bbes.?islands'},
#  {u'iso3': u'BIH', u'regex': u'herzegovina|bosnia'},
#  {u'iso3': u'BWA', u'regex': u'botswana|bechuana'},
#  {u'iso3': u'BVT', u'regex': u'bouvet'},
#  {u'iso3': u'BRA', u'regex': u'brazil'},
#  {u'iso3': u'IOT', u'regex': u'british.?indian.?ocean'},
#  {u'iso3': u'BRN', u'regex': u'brunei'},
#  {u'iso3': u'BGR', u'regex': u'bulgaria'},
#  {u'iso3': u'BFA', u'regex': u'burkina|\\bfaso|upper.?volta'},
#  {u'iso3': u'BDI', u'regex': u'burundi'},
#  {u'iso3': u'KHM', u'regex': u'cambodia|kampuchea|khmer|^p\\.?r\\.?k\\.?$'},
#  {u'iso3': u'CMR', u'regex': u'cameroon'},
#  {u'iso3': u'CAN', u'regex': u'canada'},
#  {u'iso3': u'CPV', u'regex': u'verde'},
#  {u'iso3': u'CYM', u'regex': u'cayman'},
#  {u'iso3': u'CAF', u'regex': u'\\bcen.*\\baf|^c\\.?a\\.?r\\.?$'},
#  {u'iso3': u'TCD', u'regex': u'\\bchad'},
#  {u'iso3': u'CHL', u'regex': u'\\bchile'},
#  {u'iso3': u'CHN',
#   u'regex': u'^(?!.*\\bmac)(?!.*\\bhong)(?!.*\\btai).*china|^p\\.?r\\.?c\\.?$'},
#  {u'iso3': u'CXR', u'regex': u'christmas'},
#  {u'iso3': u'CCK', u'regex': u'\\bcocos|keeling'},
#  {u'iso3': u'COL', u'regex': u'colombia'},
#  {u'iso3': u'COM', u'regex': u'comoro'},
#  {u'iso3': u'COD',
#   u'regex': u'\\bdem.*congo|congo.*\\bdem|congo.*\\bdr|\\bdr.*congo|\\bd\\.?r\\.?c|\\bd\\.?r\\.?o\\.?c|\\br\\.?d\\.?c|belgian.?congo|congo.?free.?state|kinshasa|zaire|l\\w{1,2}opoldville'},
#  {u'iso3': u'COG',
#   u'regex': u'^(?!.*\\bdem)(?!.*\\bdr)(?!.*kinshasa)(?!.*zaire)(?!.*belg)(?!.*l\\w{1,2}opoldville)(?!.*free).*\\bcongo'},
#  {u'iso3': u'COK', u'regex': u'\\bcook'},
#  {u'iso3': u'CRI', u'regex': u'costa.?rica'},
#  {u'iso3': u'CIV', u'regex': u'ivoire|ivory'},
#  {u'iso3': u'HRV', u'regex': u'croatia'},
#  {u'iso3': u'CUB', u'regex': u'\\bcuba'},
#  {u'iso3': u'CUW', u'regex': u'^(?!.*bonaire).*\\bcura(c|\xe7)ao'},
#  {u'iso3': u'CYP', u'regex': u'cyprus'},
#  {u'iso3': u'CZE', u'regex': u'^(?=.*rep).*czech|czechia|bohemia'},
#  {u'iso3': u'CSK', u'regex': u'czechoslovakia'},
#  {u'iso3': u'DNK', u'regex': u'denmark'},
#  {u'iso3': u'DJI', u'regex': u'djibouti'},
#  {u'iso3': u'DMA', u'regex': u'dominica(?!n)'},
#  {u'iso3': u'DOM', u'regex': u'dominican'},
#  {u'iso3': u'ECU', u'regex': u'ecuador'},
#  {u'iso3': u'EGY', u'regex': u'egypt'},
#  {u'iso3': u'SLV', u'regex': u'el.?salvador'},
#  {u'iso3': u'GNQ', u'regex': u'guine.*eq|eq.*guine|^(?=.*span).*guinea'},
#  {u'iso3': u'ERI', u'regex': u'eritrea'},
#  {u'iso3': u'EST', u'regex': u'estonia'},
#  {u'iso3': u'ETH', u'regex': u'ethiopia|abyssinia'},
#  {u'iso3': u'FLK', u'regex': u'falkland|malvinas'},
#  {u'iso3': u'FRO', u'regex': u'faroe|faeroe'},
#  {u'iso3': u'FJI', u'regex': u'fiji'},
#  {u'iso3': u'FIN', u'regex': u'finland'},
#  {u'iso3': u'FRA',
#   u'regex': u'^(?!.*\\bdep)(?!.*martinique).*france|french.?republic|\\bgaul'},
#  {u'iso3': u'GUF', u'regex': u'^(?=.*french).*guiana'},
#  {u'iso3': u'PYF', u'regex': u'french.?polynesia'},
#  {u'iso3': u'ATF', u'regex': u'french.?southern|\\bfr.*\\bso.*\\ban.*\\b\\bt'},
#  {u'iso3': u'GAB', u'regex': u'gabon'},
#  {u'iso3': u'GMB', u'regex': u'gambia'},
#  {u'iso3': u'GEO', u'regex': u'^(?!.*south).*georgia'},
#  {u'iso3': u'DDR',
#   u'regex': u'german.?democratic.?republic|^(d|g)\\.?d\\.?r\\.?$|^(?=.*east).*germany'},
#  {u'iso3': u'DEU',
#   u'regex': u'^(?!.*east).*germany|^(?=.*\\bfed.*\\brep).*german'},
#  {u'iso3': u'GHA', u'regex': u'ghana|gold.?coast'},
#  {u'iso3': u'GIB', u'regex': u'gibraltar'},
#  {u'iso3': u'GRC', u'regex': u'greece|hellenic|hellas'},
#  {u'iso3': u'GRL', u'regex': u'greenland'},
#  {u'iso3': u'GRD', u'regex': u'grenada'},
#  {u'iso3': u'GLP', u'regex': u'guadeloupe'},
#  {u'iso3': u'GUM', u'regex': u'\\bguam'},
#  {u'iso3': u'GTM', u'regex': u'guatemala'},
#  {u'iso3': u'GGY', u'regex': u'guernsey'},
#  {u'iso3': u'GIN',
#   u'regex': u'^(?!.*eq)(?!.*span)(?!.*bissau)(?!.*portu)(?!.*new).*guinea'},
#  {u'iso3': u'GNB', u'regex': u'bissau|^(?=.*portu).*guinea'},
#  {u'iso3': u'GUY', u'regex': u'guyana|british.?guiana'},
#  {u'iso3': u'HTI', u'regex': u'haiti'},
#  {u'iso3': u'HMD', u'regex': u'heard.*mcdonald'},
#  {u'iso3': u'VAT', u'regex': u'holy.?see|vatican|papal.?st'},
#  {u'iso3': u'HND', u'regex': u'^(?!.*brit).*honduras'},
#  {u'iso3': u'HKG', u'regex': u'hong.?kong'},
#  {u'iso3': u'HUN', u'regex': u'^(?!.*austr).*hungary'},
#  {u'iso3': u'ISL', u'regex': u'iceland'},
#  {u'iso3': u'IND', u'regex': u'india(?!.*ocea)'},
#  {u'iso3': u'IDN', u'regex': u'indonesia'},
#  {u'iso3': u'IRN', u'regex': u'\\biran|persia'},
#  {u'iso3': u'IRQ', u'regex': u'\\biraq|mesopotamia'},
#  {u'iso3': u'IRL', u'regex': u'ireland'},
#  {u'iso3': u'IMN', u'regex': u'^(?=.*isle).*\\bman'},
#  {u'iso3': u'ISR', u'regex': u'israel'},
#  {u'iso3': u'ITA', u'regex': u'italy'},
#  {u'iso3': u'JAM', u'regex': u'jamaica'},
#  {u'iso3': u'JPN', u'regex': u'japan'},
#  {u'iso3': u'JEY', u'regex': u'jersey'},
#  {u'iso3': u'JOR', u'regex': u'jordan'},
#  {u'iso3': u'KAZ', u'regex': u'kazak'},
#  {u'iso3': u'KEN',
#   u'regex': u'kenya|british.?east.?africa|east.?africa.?prot'},
#  {u'iso3': u'KIR', u'regex': u'kiribati'},
#  {u'iso3': u'PRK',
#   u'regex': u'^(?=.*dem).*\\bkorea|^(?=.*peo).*\\bkorea|^(?=.*nor).*\\bkorea|\\bd\\.?p\\.?r\\.?k'},
#  {u'iso3': u'KOR',
#   u'regex': u'^(?!.*dem)(?!.*peo)(?!.*nor).*\\bkorea|\\br\\.?o\\.?k\\b'},
#  {u'iso3': u'KWT', u'regex': u'kuwait'},
#  {u'iso3': u'KGZ', u'regex': u'kyrgyz|kirghiz'},
#  {u'iso3': u'LAO', u'regex': u'\\blaos?\\b'},
#  {u'iso3': u'LVA', u'regex': u'latvia'},
#  {u'iso3': u'LBN', u'regex': u'lebanon'},
#  {u'iso3': u'LSO', u'regex': u'lesotho|basuto'},
#  {u'iso3': u'LBR', u'regex': u'liberia'},
#  {u'iso3': u'LBY', u'regex': u'libya'},
#  {u'iso3': u'LIE', u'regex': u'liechtenstein'},
#  {u'iso3': u'LTU', u'regex': u'lithuania'},
#  {u'iso3': u'LUX', u'regex': u'^(?!.*belg).*luxem'},
#  {u'iso3': u'MAC', u'regex': u'maca(o|u)'},
#  {u'iso3': u'MKD', u'regex': u'macedonia|^f\\.?y\\.?r\\.?o\\.?m\\.?$'},
#  {u'iso3': u'MDG', u'regex': u'madagascar|malagasy'},
#  {u'iso3': u'MWI', u'regex': u'malawi|nyasa'},
#  {u'iso3': u'MYS', u'regex': u'malaysia'},
#  {u'iso3': u'MDV', u'regex': u'maldive'},
#  {u'iso3': u'MLI', u'regex': u'\\bmali\\b'},
#  {u'iso3': u'MLT', u'regex': u'\\bmalta'},
#  {u'iso3': u'MHL', u'regex': u'marshall'},
#  {u'iso3': u'MTQ', u'regex': u'martinique'},
#  {u'iso3': u'MRT', u'regex': u'mauritania'},
#  {u'iso3': u'MUS', u'regex': u'mauritius'},
#  {u'iso3': u'MYT', u'regex': u'mayotte'},
#  {u'iso3': u'MEX', u'regex': u'\\bmexic'},
#  {u'iso3': u'FSM', u'regex': u'micronesia'},
#  {u'iso3': u'MDA', u'regex': u'moldov|b(a|e)ssarabia'},
#  {u'iso3': u'MCO', u'regex': u'monaco'},
#  {u'iso3': u'MNG', u'regex': u'mongolia'},
#  {u'iso3': u'MNE', u'regex': u'^(?!.*serbia).*montenegro'},
#  {u'iso3': u'MSR', u'regex': u'montserrat'},
#  {u'iso3': u'MAR', u'regex': u'morocco|\\bmaroc'},
#  {u'iso3': u'MOZ', u'regex': u'mozambique'},
#  {u'iso3': u'MMR', u'regex': u'myanmar|burma'},
#  {u'iso3': u'NAM', u'regex': u'namibia'},
#  {u'iso3': u'NRU', u'regex': u'nauru'},
#  {u'iso3': u'NPL', u'regex': u'nepal'},
#  {u'iso3': u'NLD', u'regex': u'^(?!.*\\bant)(?!.*\\bcarib).*netherlands'},
#  {u'iso3': u'ANT', u'regex': u'^(?=.*\\bant).*(nether|dutch)'},
#  {u'iso3': u'NCL', u'regex': u'new.?caledonia'},
#  {u'iso3': u'NZL', u'regex': u'new.?zealand'},
#  {u'iso3': u'NIC', u'regex': u'nicaragua'},
#  {u'iso3': u'NER', u'regex': u'\\bniger(?!ia)'},
#  {u'iso3': u'NGA', u'regex': u'nigeria'},
#  {u'iso3': u'NIU', u'regex': u'niue'},
#  {u'iso3': u'NFK', u'regex': u'norfolk'},
#  {u'iso3': u'MNP', u'regex': u'mariana'},
#  {u'iso3': u'NOR', u'regex': u'norway'},
#  {u'iso3': u'OMN', u'regex': u'\\boman|trucial'},
#  {u'iso3': u'PAK', u'regex': u'^(?!.*east).*paki?stan'},
#  {u'iso3': u'PLW', u'regex': u'palau'},
#  {u'iso3': u'PSE', u'regex': u'palestin|\\bgaza|west.?bank'},
#  {u'iso3': u'PAN', u'regex': u'panama'},
#  {u'iso3': u'PNG',
#   u'regex': u'papua|\\bp.*\\bn.*\\bguin.*|^p\\.?n\\.?g\\.?$|new.?guinea'},
#  {u'iso3': u'PRY', u'regex': u'paraguay'},
#  {u'iso3': u'PER', u'regex': u'peru'},
#  {u'iso3': u'PHL', u'regex': u'philippines'},
#  {u'iso3': u'PCN', u'regex': u'pitcairn'},
#  {u'iso3': u'POL', u'regex': u'poland'},
#  {u'iso3': u'PRT', u'regex': u'portugal'},
#  {u'iso3': u'PRI', u'regex': u'puerto.?rico'},
#  {u'iso3': u'QAT', u'regex': u'qatar'},
#  {u'iso3': u'REU', u'regex': u'r(e|\xe9)union'},
#  {u'iso3': u'ROU', u'regex': u'r(o|u|ou)mania'},
#  {u'iso3': u'RUS',
#   u'regex': u'\\brussia|soviet.?union|u\\.?s\\.?s\\.?r|socialist.?republics'},
#  {u'iso3': u'RWA', u'regex': u'rwanda'},
#  {u'iso3': u'BLM', u'regex': u'barth(e|\xe9)lemy'},
#  {u'iso3': u'SHN', u'regex': u'helena'},
#  {u'iso3': u'KNA', u'regex': u'kitts|\\bnevis'},
#  {u'iso3': u'LCA', u'regex': u'\\blucia'},
#  {u'iso3': u'MAF',
#   u'regex': u'^(?=.*collectivity).*martin|^(?=.*france).*martin(?!ique)|^(?=.*french).*martin(?!ique)'},
#  {u'iso3': u'SPM', u'regex': u'miquelon'},
#  {u'iso3': u'VCT', u'regex': u'vincent'},
#  {u'iso3': u'WSM', u'regex': u'^(?!.*amer).*samoa'},
#  {u'iso3': u'SMR', u'regex': u'san.?marino'},
#  {u'iso3': u'STP', u'regex': u'\\bs(a|\xe3)o.?tom(e|\xe9)'},
#  {u'iso3': u'SAU', u'regex': u'\\bsa\\w*.?arabia'},
#  {u'iso3': u'SEN', u'regex': u'senegal'},
#  {u'iso3': u'SRB', u'regex': u'^(?!.*monte).*serbia'},
#  {u'iso3': u'SYC', u'regex': u'seychell'},
#  {u'iso3': u'SLE', u'regex': u'sierra'},
#  {u'iso3': u'SGP', u'regex': u'singapore'},
#  {u'iso3': u'SXM', u'regex': u'^(?!.*martin)(?!.*saba).*maarten'},
#  {u'iso3': u'SVK', u'regex': u'^(?!.*cze).*slovak'},
#  {u'iso3': u'SVN', u'regex': u'slovenia'},
#  {u'iso3': u'SLB', u'regex': u'solomon'},
#  {u'iso3': u'SOM', u'regex': u'somali'},
#  {u'iso3': u'ZAF', u'regex': u'\\bs\\w*.?africa'},
#  {u'iso3': u'SGS', u'regex': u'south.?georgia|sandwich'},
#  {u'iso3': u'SSD', u'regex': u'\\bs\\w*.?sudan'},
#  {u'iso3': u'ESP', u'regex': u'spain'},
#  {u'iso3': u'LKA', u'regex': u'sri.?lanka|ceylon'},
#  {u'iso3': u'SDN', u'regex': u'^(?!.*\\bs(?!u)).*sudan'},
#  {u'iso3': u'SUR', u'regex': u'surinam|dutch.?guiana'},
#  {u'iso3': u'SJM', u'regex': u'svalbard'},
#  {u'iso3': u'SWZ', u'regex': u'swaziland'},
#  {u'iso3': u'SWE', u'regex': u'sweden'},
#  {u'iso3': u'CHE', u'regex': u'switz|swiss'},
#  {u'iso3': u'SYR', u'regex': u'syria'},
#  {u'iso3': u'TWN', u'regex': u'taiwan|taipei|formosa'},
#  {u'iso3': u'TJK', u'regex': u'tajik'},
#  {u'iso3': u'TZA', u'regex': u'tanzania'},
#  {u'iso3': u'THA', u'regex': u'thailand|\\bsiam'},
#  {u'iso3': u'TLS', u'regex': u'^(?=.*leste).*timor|^(?=.*east).*timor'},
#  {u'iso3': u'TGO', u'regex': u'togo'},
#  {u'iso3': u'TKL', u'regex': u'tokelau'},
#  {u'iso3': u'TON', u'regex': u'tonga'},
#  {u'iso3': u'TTO', u'regex': u'trinidad|tobago'},
#  {u'iso3': u'TUN', u'regex': u'tunisia'},
#  {u'iso3': u'TUR', u'regex': u'turkey'},
#  {u'iso3': u'TKM', u'regex': u'turkmen'},
#  {u'iso3': u'TCA', u'regex': u'turks'},
#  {u'iso3': u'TUV', u'regex': u'tuvalu'},
#  {u'iso3': u'UGA', u'regex': u'uganda'},
#  {u'iso3': u'UKR', u'regex': u'ukrain'},
#  {u'iso3': u'ARE', u'regex': u'emirates|^u\\.?a\\.?e\\.?$|united.?arab.?em'},
#  {u'iso3': u'GBR', u'regex': u'united.?kingdom|britain|^u\\.?k\\.?$'},
#  {u'iso3': u'USA',
#   u'regex': u'^(?!.*islands).*united.?states|^u\\.?s\\.?a\\.?$|^u\\.?s\\.?$'},
#  {u'iso3': u'UMI', u'regex': u'minor.?outlying.?is'},
#  {u'iso3': u'URY', u'regex': u'uruguay'},
#  {u'iso3': u'UZB', u'regex': u'uzbek'},
#  {u'iso3': u'VUT', u'regex': u'vanuatu|new.?hebrides'},
#  {u'iso3': u'VEN', u'regex': u'venezuela'},
#  {u'iso3': u'VNM',
#   u'regex': u'^(?!.*republic).*viet.?nam|^(?=.*socialist).*viet.?nam'},
#  {u'iso3': u'VGB',
#   u'regex': u'^(?=.*\\bu\\.?\\s?k).*virgin|^(?=.*brit).*virgin|^(?=.*kingdom).*virgin'},
#  {u'iso3': u'VIR',
#   u'regex': u'^(?=.*\\bu\\.?\\s?s).*virgin|^(?=.*states).*virgin'},
#  {u'iso3': u'WLF', u'regex': u'futuna|wallis'},
#  {u'iso3': u'ESH', u'regex': u'sahara'},
#  {u'iso3': u'YEM',
#   u'regex': u'^(?!.*arab)(?!.*north)(?!.*sana)(?!.*peo)(?!.*dem)(?!.*south)(?!.*aden)(?!.*\\bp\\.?d\\.?r).*yemen'},
#  {u'iso3': u'YMD',
#   u'regex': u'^(?=.*peo).*yemen|^(?!.*rep)(?=.*dem).*yemen|^(?=.*south).*yemen|^(?=.*aden).*yemen|^(?=.*\\bp\\.?d\\.?r).*yemen'},
#  {u'iso3': u'YUG', u'regex': u'yugoslavia'},
#  {u'iso3': u'ZMB', u'regex': u'zambia|northern.?rhodesia'},
#  {u'iso3': u'EAZ', u'regex': u'zanz'},
#  {u'iso3': u'ZWE', u'regex': u'zimbabwe|^(?!.*northern).*rhodesia'}]

# %% [markdown]
# Loop through all the countries in the dataset. For each country, try each of the regular expressions of the above JSON. When a match is found, append the data lists.

# %%
locations = []
pops = []
lExps = []
gdps = []

# keep track of country names that do not match to a regex
countries_no_match = []

for country, pop, lExp, gdp in zip(df['country'], df['pop'], df['lifeExp'], df['gdpPercap']):
    for item in get_iso3:
        # N.B. an empty list in python is falsy
        if re.findall(item['regex'], country.lower()):
            locations.append(item['iso3'])
            pops.append(pop / 1e6)
            lExps.append(lExp)
            gdps.append(gdp)
            break
    else:
        print(country.lower())
        losers.append(country)

# %%
len(locations), len(df['country']), len(countries_no_match)

# all countries have found a match!
# Out:
# (142, 142, 0)

# %% [markdown]
# Define a plot function

# %%
def plot(z, title, units):
    if units == '$':
        colorbar= dict(
            tickprefix=' ' + units,
            showtickprefix='last'   
        )
    else:
        colorbar = dict(
            ticksuffix=' ' + units,
            showticksuffix='last'
        )
    
    url = py.plot(
        dict(
            data=[
                dict(
                    type='choropleth',
                    locations=locations,
                    z=z,
                    colorbar=colorbar
                )
            ],
            layout=dict(
                title=title + ' by country in ' + str(the_year),
                titlefont=dict(
                    size=22
                ),
                geo=dict(
                    projection=dict(
                        type='kavrayskiy7'
                    )
                ),
                width=1000,
                height=600
            )
        ),
        validate=False,
        filename=title.lower().replace(' ', '-'),
        auto_open=False
    )
    print(url)

# %% [markdown]
# Use the plot function for each of the three dependent variables

# %%
plot(pops, 'World population', 'million')
plot(lExps, 'Life expectancy', 'year')
plot(gdps, 'GDP per capita', '$')
# Out:
# https://plot.ly/~etpinard/4250
# https://plot.ly/~etpinard/4252
# https://plot.ly/~etpinard/4254

# %%
tls.embed('https://plot.ly/~etpinard/4250')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/4250.embed" height="525" width="100%"></iframe>

# %% [markdown]
# We note that the Russia is not part of the dataset.

# %%
tls.embed('https://plot.ly/~etpinard/4252')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/4252.embed" height="525" width="100%"></iframe>

# %%
tls.embed('https://plot.ly/~etpinard/4254')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/4254.embed" height="525" width="100%"></iframe>

# %%
# Inject CSS styling in the NB
from IPython.display import display, HTML
display(HTML(open('../_custom.css').read()))
# Out:
# <style>
#     h1 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#         padding-bottom: 1em;
#         text-align: center;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 40pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0em;
#         margin-top: 0em;
#         display: block;
#         white-space: nowrap;
#     }
#     h2 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#         text-indent:1em;
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 20pt;
#         font-style: italic;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 1.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h3 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#         padding-left: 1em
#     }
#     .text_cell_render h3 {
#         font-weight: 300;
#         font-size: 18pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0.5em;
#         margin-top: 2em;
#         display: block;
#         white-space: nowrap;
#     }
#     h4 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h4 {
#         font-weight: 300;
#         font-size: 16pt;
#         color:#447adb;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h5 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-style: normal;
#         color: #1d3b84;
#         font-size: 16pt;
#         margin-bottom: 0em;
#         margin-top: 1.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     div.inner_cell {
#         display: inline;
#     }
#     div.text_cell_render{
#         font-family: "Open sans",verdana,arial,sans-serif;
#         line-height: 135%;
#         font-size: 125%;
#         margin-left:auto;
#         margin-right:auto;
#         text-align:justify;
#         text-justify:inter-word;
#     }
#     div.output_subarea.output_text.output_pyout {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 300px;
#     }
#     div.output_subarea.output_stream.output_stdout.output_text {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 300px;
#     }
#     div.output_subarea.output_html.rendered_html {
#         overflow-x: scroll;
#         max-width: 100%;
#       /*  overflow-y: scroll; */
#       /*  max-height: 300px;   */
#     }
#     code{
#       font-size: 78%;
#     }
#     .rendered_html code{
#         background-color: transparent;
#         white-space: inherit;
#     }
#     ul{
#         /* color:#447adb; */
#         margin: 2em;
#     }
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     ul li li{
#         padding-left: 0.2em;
#         margin-bottom: 0.2em;
#         margin-top: 0.2em;
#     }
#     ol{
#         /* color:#447adb; */
#         margin: 2em;
#     }
#     ol li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     /*.prompt{
#         display: None;
#     } */
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.2em;
#     }
#     a:link{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:visited{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:hover{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:focus{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:active{
#        font-weight: bold;
#        color:#447adb;
#     }
#     .rendered_html :link {
#        text-decoration: none;
#     }
#     .rendered_html :hover {
#        text-decoration: none;
#     }
#     .rendered_html :visited {
#       text-decoration: none;
#     }
#     .rendered_html :focus {
#       text-decoration: none;
#     }
#     .rendered_html :active {
#       text-decoration: none;
#     }
#     .warning{
#         color: rgb( 240, 20, 20 )
#     }
#     hr {
#       color: #f3f3f3;
#       background-color: #f3f3f3;
#       height: 1px;
#     }
#     blockquote{
#       display:block;
#       background: #f3f3f3;
#       font-family: "Open sans",verdana,arial,sans-serif;
#       padding: 15px 15px 15px 15px;
#       text-align:justify;
#       text-justify:inter-word;
#       }
#       blockquote p {
#         margin-bottom: 0;
#         line-height: 125%;
#         font-size: 100%;
#         text-align: center;
#       }
#    /* element.style {
#     } */
# </style>
# <script>
#     MathJax.Hub.Config({
#         TeX: {
#             extensions: ["AMSmath.js"]
#         },
#         tex2jax: {
#             inlineMath: [ ["$","$"], ["\\(","\\)"] ],
#             displayMath: [ ["$$","$$"], ["\\[","\\]"] ]
#         },
#         displayAlign: "center", // Change this to "center" to center equations.
#         "HTML-CSS": {
#             styles: {".MathJax_Display": {"margin": 4}}
#         }
#     });
# </script>
